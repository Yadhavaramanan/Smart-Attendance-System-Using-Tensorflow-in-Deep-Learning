# %%
import tensorflow as tf

# Updated dictionary of student register numbers and names
students = {
    "927622BAL001": "ALAGUTHAMIL",
    "927622BAL002": "ARIVALAGAN",
    "927622BAL003": "BALAMURUGAN ",
    "927622BAL004": "BARANI ",
    "927622BAL005": "BARATH ",
    "927622BAL006": "BAVANA ",
    "927622BAL007": "CHANTHIRAN ",
    "927622BAL008": "DEEPAK ",
    "927622BAL009": "ELANGO ",
    "927622BAL010": "FERNANDOS ",
    "927622BAL011": "GOKULA KRISHNA ",
    "927622BAL012": "GOKUL ",
    "927622BAL013": "HARISH ",
    "927622BAL014": "JAYALAKSHMI ",
    "927622BAL015": "JEEVAN ",
    "927622BAL016": "JEEVITHA ",
    "927622BAL017": "KALYAN SINGH ",
    "927622BAL018": "LOKESH KANAGARAJ ",
    "927622BAL019": "MARAN ",
    "927622BAL020": "NAVANEETHA KANNAN ",
    "927622BAL021": "PRANITHA ",
    "927622BAL022": "PRANESH ",
    "927622BAL023": "PRASANTH ",
    "927622BAL024": "RESHMA ",
    "927622BAL025": "ROOPA SRI ",
    "927622BAL026": "ROHIT ",
    "927622BAL027": "SATHYA DEV ",
    "927622BAL028": "THILAGAN ",
    "927622BAL029": "THILLAI NATHAN ",
    "927622BAL030": "THILAK ",
    "927622BAL031": "THIVAN ",
    "927622BAL032": "THIRU ",
    "927622BAL033": "THANGARAJ ",
    "927622BAL034": "UDAYA ",
    "927622BAL035": "UMA SRI ",
    "927622BAL036": "UMA MAGESH ",
    "927622BAL037": "VIJAY RAJENDRAN ",
    "927622BAL038": "VIJAY GURUMOORTHY ",
    "927622BAL039": "VIJAY KUMAR ",
    "927622BAL040": "YOGESH ",
    "927622BAL041": "YAMUNA ",
    "927622BAL055": "YADHAVARAMANAN "
}

# List of absent students by their register numbers
absent_students = ["927622BAL003", "927622BAL008", "927622BAL013", "927622BAL021", "927622BAL028"]

# Calculate the number of present students
total_students = len(students)
absent_count = len(absent_students)
present_count = tf.subtract(total_students, absent_count)

# Display the total number of present students
print(f"Total number of students present: {present_count.numpy()}")

# Display attendance with fingerprint symbols
print("\nAttendance with fingerprint symbols:")
for reg_no, name in students.items():
    if reg_no in absent_students:
        print(f"{reg_no} - {name}: ❌ (Absent)")
    else:
        print(f"{reg_no} - {name}: ✅ (Present)")

# Display the list of absent students separately
print("\nAbsent students:")
for reg_no in absent_students:
    print(f"{reg_no} - {students[reg_no]}")
# Out:
# Total number of students present: 37
#
# Attendance with fingerprint symbols:
# 927622BAL001 - ALAGUTHAMIL: ✅ (Present)
# 927622BAL002 - ARIVALAGAN: ✅ (Present)
# 927622BAL003 - BALAMURUGAN : ❌ (Absent)
# 927622BAL004 - BARANI : ✅ (Present)
# 927622BAL005 - BARATH : ✅ (Present)
# 927622BAL006 - BAVANA : ✅ (Present)
# 927622BAL007 - CHANTHIRAN : ✅ (Present)
# 927622BAL008 - DEEPAK : ❌ (Absent)
# 927622BAL009 - ELANGO : ✅ (Present)
# 927622BAL010 - FERNANDOS : ✅ (Present)
# 927622BAL011 - GOKULA KRISHNA : ✅ (Present)
# 927622BAL012 - GOKUL : ✅ (Present)
# 927622BAL013 - HARISH : ❌ (Absent)
# 927622BAL014 - JAYALAKSHMI : ✅ (Present)
# 927622BAL015 - JEEVAN : ✅ (Present)
# 927622BAL016 - JEEVITHA : ✅ (Present)
# 927622BAL017 - KALYAN SINGH : ✅ (Present)
# 927622BAL018 - LOKESH KANAGARAJ : ✅ (Present)
# 927622BAL019 - MARAN : ✅ (Present)
# 927622BAL020 - NAVANEETHA KANNAN : ✅ (Present)
# 927622BAL021 - PRANITHA : ❌ (Absent)
# 927622BAL022 - PRANESH : ✅ (Present)
# ...
